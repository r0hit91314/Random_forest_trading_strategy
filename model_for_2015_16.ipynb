# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
nifty_50_symbols = [
    "ADANIENT.NS", "ADANIPORTS.NS", "ASIANPAINT.NS", "AXISBANK.NS", "BAJAJ-AUTO.NS",
    "BAJFINANCE.NS", "BAJAJFINSV.NS", "BPCL.NS", "BHARTIARTL.NS", "BRITANNIA.NS",
    "CIPLA.NS", "COALINDIA.NS", "DIVISLAB.NS", "DRREDDY.NS", "EICHERMOT.NS",
    "GRASIM.NS", "HCLTECH.NS", "HDFCBANK.NS", "HEROMOTOCO.NS",
    "HINDALCO.NS", "HINDUNILVR.NS", "ICICIBANK.NS", "ITC.NS", "INDUSINDBK.NS",
    "INFY.NS", "JSWSTEEL.NS", "KOTAKBANK.NS", "LT.NS",
    "M&M.NS", "MARUTI.NS", "NESTLEIND.NS", "NTPC.NS", "ONGC.NS",
    "POWERGRID.NS", "RELIANCE.NS", "SBIN.NS", "SUNPHARMA.NS",
    "TCS.NS", "TATACONSUM.NS", "TATAMOTORS.NS", "TATASTEEL.NS", "TECHM.NS",
    "TITAN.NS", "UPL.NS", "ULTRACEMCO.NS", "WIPRO.NS", "HINDPETRO.NS"
]
start_date = "2012-01-01"
end_date = "2015-01-01"

trading_data = {}

for symbol in nifty_50_symbols:
    df = yf.download(symbol, start=start_date, end=end_date)[['Open', 'Close']]
    df.dropna(inplace=True)
    trading_data[symbol] = df
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
df = pd.DataFrame(columns=[f"col_{i}" for i in range(93)])
y_arr = []
for symbol in nifty_50_symbols:
    for t in range(241, len(trading_data[symbol])):
        t_arr = []
        
        # ---- First lag set: m in {1, 2, ..., 20}
        for m in range(1, 21):
            ir_t_m = float(trading_data[symbol]["Close"].iloc[t - m] / trading_data[symbol]["Open"].iloc[t - m] - 1)
            cr_t_m = float(trading_data[symbol]["Close"].iloc[t - 1] / trading_data[symbol]["Close"].iloc[t - 1 - m] - 1)
            or_t_m = float(trading_data[symbol]["Open"].iloc[t] / trading_data[symbol]["Close"].iloc[t - m] - 1)
            
            t_arr.extend([ir_t_m, cr_t_m, or_t_m])  # ✅ use extend for cleaner code

        # ---- Second lag set: m in {40, 60, ..., 240}
        for m in range(40, 241, 20):
            ir_t_m = float(trading_data[symbol]["Close"].iloc[t - m] / trading_data[symbol]["Open"].iloc[t - m] - 1)
            cr_t_m = float(trading_data[symbol]["Close"].iloc[t - 1] / trading_data[symbol]["Close"].iloc[t - 1 - m] - 1)
            or_t_m = float(trading_data[symbol]["Open"].iloc[t] / trading_data[symbol]["Close"].iloc[t - m] - 1)
            
            t_arr.extend([ir_t_m, cr_t_m, or_t_m])

        # ✅ Now append only clean float values
        df.loc[len(df)] = t_arr
        
        # ✅ Compute the target as a float
        target = float(trading_data[symbol]["Close"].iloc[t] / trading_data[symbol]["Open"].iloc[t] - 1)
        y_arr.append(target)

    print(f"Processed symbol: {symbol}")

# ✅ Assign final target column
df["target"] = y_arr
# Out:
# Processed symbol: ADANIENT.NS
# Processed symbol: ADANIPORTS.NS
# Processed symbol: ASIANPAINT.NS
# Processed symbol: AXISBANK.NS
# Processed symbol: BAJAJ-AUTO.NS
# Processed symbol: BAJFINANCE.NS
# Processed symbol: BAJAJFINSV.NS
# Processed symbol: BPCL.NS
# Processed symbol: BHARTIARTL.NS
# Processed symbol: BRITANNIA.NS
# Processed symbol: CIPLA.NS
# Processed symbol: COALINDIA.NS
# Processed symbol: DIVISLAB.NS
# Processed symbol: DRREDDY.NS
# Processed symbol: EICHERMOT.NS
# Processed symbol: GRASIM.NS
# Processed symbol: HCLTECH.NS
# Processed symbol: HDFCBANK.NS
# Processed symbol: HEROMOTOCO.NS
# Processed symbol: HINDALCO.NS
# Processed symbol: HINDUNILVR.NS
# Processed symbol: ICICIBANK.NS
# Processed symbol: ITC.NS
# Processed symbol: INDUSINDBK.NS
# Processed symbol: INFY.NS
# Processed symbol: JSWSTEEL.NS
# Processed symbol: KOTAKBANK.NS
# Processed symbol: LT.NS
# Processed symbol: M&M.NS
# Processed symbol: MARUTI.NS
# Processed symbol: NESTLEIND.NS
# Processed symbol: NTPC.NS
# Processed symbol: ONGC.NS
# Processed symbol: POWERGRID.NS
# Processed symbol: RELIANCE.NS
# Processed symbol: SBIN.NS
# Processed symbol: SUNPHARMA.NS
# Processed symbol: TCS.NS
# Processed symbol: TATACONSUM.NS
# Processed symbol: TATAMOTORS.NS
# Processed symbol: TATASTEEL.NS
# Processed symbol: TECHM.NS
# Processed symbol: TITAN.NS
# Processed symbol: UPL.NS
# Processed symbol: ULTRACEMCO.NS
# Processed symbol: WIPRO.NS
# Processed symbol: HINDPETRO.NS

# %%
from sklearn.ensemble import RandomForestRegressor
# Extract features (X) and target (y)
X_train = df.drop(columns=["target"])
y_train = df["target"]

# Compute max_features = ⌊sqrt(p)⌋ where p = number of features
p = X_train.shape[1]
max_features = int(np.sqrt(p))

# Initialize the Random Forest model
rf_model = RandomForestRegressor(
    n_estimators=1000,
    max_depth=10,
    max_features=max_features,
    random_state=42,
    n_jobs=-1
)

# Fit the model
rf_model.fit(X_train, y_train)
import joblib
# Save the model
joblib.dump(rf_model, 'random_forest_model_2015_16.pkl')
# Out:
# ['random_forest_model_2015_16.pkl']

# %%
for symbols in nifty_50_symbols:
    print(len(trading_data[symbols]), end=", ")
# Out:
# 737, 737, 737, 737, 737, 737, 737, 737, 737, 737, 737, 737, 737, 737, 737, 737, 737, 737, 737, 737, 737, 737, 737, 737, 737, 737, 737, 737, 737, 737, 737, 737, 737, 737, 737, 737, 737, 737, 737, 737, 737, 737, 737, 737, 737, 737, 737,

# %%
import joblib

# Load the model using joblib
rf_model = joblib.load('random_forest_model_2015_16.pkl')

# %%
start_date = "2012-01-01"
end_date = "2016-01-01"
trading_data = {}

for symbol in nifty_50_symbols:
    df = yf.download(symbol, start=start_date, end=end_date)[['Open', 'Close']]
    df.dropna(inplace=True)
    trading_data[symbol] = df
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
for symbols in nifty_50_symbols:
    print(len(trading_data[symbols]), end=", ")
# Out:
# 983, 983, 983, 983, 983, 983, 983, 983, 983, 983, 983, 983, 983, 983, 983, 983, 983, 983, 983, 983, 983, 983, 983, 983, 983, 983, 983, 983, 983, 983, 983, 983, 983, 983, 983, 983, 983, 983, 983, 983, 983, 983, 983, 983, 983, 983, 983,

# %%
df_list = []
for symbol in nifty_50_symbols:
    df = pd.DataFrame(columns=[f"col_{i}" for i in range(93)])
    y_arr = []

    for t in range(740, len(trading_data[symbol])):
        t_arr = []
        
        # ---- First lag set: m in {1, 2, ..., 20}
        for m in range(1, 21):
            ir_t_m = float(trading_data[symbol]["Close"].iloc[t - m] / trading_data[symbol]["Open"].iloc[t - m] - 1)
            cr_t_m = float(trading_data[symbol]["Close"].iloc[t - 1] / trading_data[symbol]["Close"].iloc[t - 1 - m] - 1)
            or_t_m = float(trading_data[symbol]["Open"].iloc[t] / trading_data[symbol]["Close"].iloc[t - m] - 1)
            
            t_arr.extend([ir_t_m, cr_t_m, or_t_m])  # ✅ use extend for cleaner code

        # ---- Second lag set: m in {40, 60, ..., 240}
        for m in range(40, 241, 20):
            ir_t_m = float(trading_data[symbol]["Close"].iloc[t - m] / trading_data[symbol]["Open"].iloc[t - m] - 1)
            cr_t_m = float(trading_data[symbol]["Close"].iloc[t - 1] / trading_data[symbol]["Close"].iloc[t - 1 - m] - 1)
            or_t_m = float(trading_data[symbol]["Open"].iloc[t] / trading_data[symbol]["Close"].iloc[t - m] - 1)
            
            t_arr.extend([ir_t_m, cr_t_m, or_t_m])

        # ✅ Now append only clean float values
        df.loc[len(df)] = t_arr
        
        # ✅ Compute the target as a float
        target = float(trading_data[symbol]["Close"].iloc[t] / trading_data[symbol]["Open"].iloc[t] - 1)
        y_arr.append(target)

    # ✅ Assign final target column
    df["target"] = y_arr
    df_list.append(df)
    print(f"Processed symbol: {symbol}")
# Out:
# Processed symbol: ADANIENT.NS
# Processed symbol: ADANIPORTS.NS
# Processed symbol: ASIANPAINT.NS
# Processed symbol: AXISBANK.NS
# Processed symbol: BAJAJ-AUTO.NS
# Processed symbol: BAJFINANCE.NS
# Processed symbol: BAJAJFINSV.NS
# Processed symbol: BPCL.NS
# Processed symbol: BHARTIARTL.NS
# Processed symbol: BRITANNIA.NS
# Processed symbol: CIPLA.NS
# Processed symbol: COALINDIA.NS
# Processed symbol: DIVISLAB.NS
# Processed symbol: DRREDDY.NS
# Processed symbol: EICHERMOT.NS
# Processed symbol: GRASIM.NS
# Processed symbol: HCLTECH.NS
# Processed symbol: HDFCBANK.NS
# Processed symbol: HEROMOTOCO.NS
# Processed symbol: HINDALCO.NS
# Processed symbol: HINDUNILVR.NS
# Processed symbol: ICICIBANK.NS
# Processed symbol: ITC.NS
# Processed symbol: INDUSINDBK.NS
# Processed symbol: INFY.NS
# Processed symbol: JSWSTEEL.NS
# Processed symbol: KOTAKBANK.NS
# Processed symbol: LT.NS
# Processed symbol: M&M.NS
# Processed symbol: MARUTI.NS
# Processed symbol: NESTLEIND.NS
# Processed symbol: NTPC.NS
# Processed symbol: ONGC.NS
# Processed symbol: POWERGRID.NS
# Processed symbol: RELIANCE.NS
# Processed symbol: SBIN.NS
# Processed symbol: SUNPHARMA.NS
# Processed symbol: TCS.NS
# Processed symbol: TATACONSUM.NS
# Processed symbol: TATAMOTORS.NS
# Processed symbol: TATASTEEL.NS
# Processed symbol: TECHM.NS
# Processed symbol: TITAN.NS
# Processed symbol: UPL.NS
# Processed symbol: ULTRACEMCO.NS
# Processed symbol: WIPRO.NS
# Processed symbol: HINDPETRO.NS

# %%
for i in range(len(df_list)):
    print(f"DataFrame {i} shape: {len(df_list[i])}")
# Out:
# DataFrame 0 shape: 243
# DataFrame 1 shape: 243
# DataFrame 2 shape: 243
# DataFrame 3 shape: 243
# DataFrame 4 shape: 243
# DataFrame 5 shape: 243
# DataFrame 6 shape: 243
# DataFrame 7 shape: 243
# DataFrame 8 shape: 243
# DataFrame 9 shape: 243
# DataFrame 10 shape: 243
# DataFrame 11 shape: 243
# DataFrame 12 shape: 243
# DataFrame 13 shape: 243
# DataFrame 14 shape: 243
# DataFrame 15 shape: 243
# DataFrame 16 shape: 243
# DataFrame 17 shape: 243
# DataFrame 18 shape: 243
# DataFrame 19 shape: 243
# DataFrame 20 shape: 243
# DataFrame 21 shape: 243
# DataFrame 22 shape: 243
# DataFrame 23 shape: 243
# DataFrame 24 shape: 243
# DataFrame 25 shape: 243
# DataFrame 26 shape: 243
# DataFrame 27 shape: 243
# DataFrame 28 shape: 243
# DataFrame 29 shape: 243
# DataFrame 30 shape: 243
# DataFrame 31 shape: 243
# DataFrame 32 shape: 243
# DataFrame 33 shape: 243
# DataFrame 34 shape: 243
# DataFrame 35 shape: 243
# DataFrame 36 shape: 243
# DataFrame 37 shape: 243
# DataFrame 38 shape: 243
# DataFrame 39 shape: 243
# DataFrame 40 shape: 243
# DataFrame 41 shape: 243
# DataFrame 42 shape: 243
# DataFrame 43 shape: 243
# DataFrame 44 shape: 243
# DataFrame 45 shape: 243
# DataFrame 46 shape: 243

# %%
joblib.dump(df_list, 'trading_data_list_15_16.pkl')
# Out:
# ['trading_data_list_15_16.pkl']

# %%
intial_fund = 10000000
portfolio_size = intial_fund
portfolio_list = []

# %%
for day_no in range(len(df_list[i])):
    investment_per_stock = portfolio_size / 20
    day_no = day_no+1
    day_intraday_return_list = []
    for i in range(len(df_list)):
        input_row = df_list[i].drop(columns=["target"]).iloc[day_no-1:day_no]  # shape (1, 93)
        predicted_value = rf_model.predict(input_row)
        day_intraday_return_list.append(predicted_value[0])  # Append the predicted value

    arr = np.array(day_intraday_return_list)
    # Get indices of top 10 values
    top_10_indices = arr.argsort()[-10:][::-1]  # last 10, reversed for descending
    # Get indices of bottom 10 values
    bottom_10_indices = arr.argsort()[:10]  # first 10 for smallest values
    portfolio_size = 0
    for i in range(10):
        portfolio_size += investment_per_stock * (1 + df_list[top_10_indices[i]]["target"].iloc[day_no-1])
        portfolio_size += investment_per_stock * (1 - df_list[bottom_10_indices[i]]["target"].iloc[day_no-1])

    portfolio_list.append(portfolio_size)
    print(f"Portfolio value after day {day_no}: {portfolio_size:.2f}")
# Out:
# Portfolio value after day 1: 9968403.09
# Portfolio value after day 2: 9934974.06
# Portfolio value after day 3: 9979118.11
# Portfolio value after day 4: 9994157.67
# Portfolio value after day 5: 9992793.01
# Portfolio value after day 6: 10014945.07
# Portfolio value after day 7: 10015956.91
# Portfolio value after day 8: 10069002.60
# Portfolio value after day 9: 10082105.29
# Portfolio value after day 10: 10139479.58
# Portfolio value after day 11: 10194719.56
# Portfolio value after day 12: 10231277.08
# Portfolio value after day 13: 10224792.76
# Portfolio value after day 14: 10263907.71
# Portfolio value after day 15: 10234929.11
# Portfolio value after day 16: 10236858.26
# Portfolio value after day 17: 10272158.21
# Portfolio value after day 18: 10220918.19
# Portfolio value after day 19: 10205097.22
# Portfolio value after day 20: 10294331.52
# Portfolio value after day 21: 10311955.82
# Portfolio value after day 22: 10301093.35
# Portfolio value after day 23: 10312798.76
# Portfolio value after day 24: 10324517.56
# Portfolio value after day 25: 10491481.62
# Portfolio value after day 26: 10423186.32
# Portfolio value after day 27: 10457050.15
# Portfolio value after day 28: 10586226.66
# Portfolio value after day 29: 10632774.48
# Portfolio value after day 30: 10698300.18
# Portfolio value after day 31: 10712195.28
# Portfolio value after day 32: 10736110.64
# Portfolio value after day 33: 10816210.23
# Portfolio value after day 34: 10840077.07
# Portfolio value after day 35: 10854887.67
# Portfolio value after day 36: 10866142.02
# Portfolio value after day 37: 10814654.24
# Portfolio value after day 38: 10803640.63
# Portfolio value after day 39: 10780479.42
# Portfolio value after day 40: 10911611.11
# Portfolio value after day 41: 10966727.98
# Portfolio value after day 42: 10968337.06
# Portfolio value after day 43: 11021982.48
# Portfolio value after day 44: 11070430.94
# Portfolio value after day 45: 11134631.07
# Portfolio value after day 46: 11164784.11
# Portfolio value after day 47: 11173671.01
# Portfolio value after day 48: 11211687.93
# Portfolio value after day 49: 11249293.10
# Portfolio value after day 50: 11259779.29
# Portfolio value after day 51: 11310431.46
# Portfolio value after day 52: 11366145.48
# Portfolio value after day 53: 11387916.31
# Portfolio value after day 54: 11475585.21
# Portfolio value after day 55: 11530459.81
# Portfolio value after day 56: 11538634.53
# Portfolio value after day 57: 11558398.32
# Portfolio value after day 58: 11609570.64
# Portfolio value after day 59: 11626520.38
# Portfolio value after day 60: 11655407.93
# Portfolio value after day 61: 11647846.55
# Portfolio value after day 62: 11651779.21
# Portfolio value after day 63: 11711107.59
# Portfolio value after day 64: 11707077.72
# Portfolio value after day 65: 11782951.54
# Portfolio value after day 66: 11768656.81
# Portfolio value after day 67: 11778181.09
# Portfolio value after day 68: 11838322.74
# Portfolio value after day 69: 11889841.90
# Portfolio value after day 70: 11974365.96
# Portfolio value after day 71: 11955168.29
# Portfolio value after day 72: 12021454.59
# Portfolio value after day 73: 12035404.88
# Portfolio value after day 74: 12115735.26
# Portfolio value after day 75: 12125109.74
# Portfolio value after day 76: 12127188.72
# Portfolio value after day 77: 12143838.32
# Portfolio value after day 78: 12203309.71
# Portfolio value after day 79: 12181530.92
# Portfolio value after day 80: 12101448.78
# Portfolio value after day 81: 12074518.43
# Portfolio value after day 82: 12016161.46
# Portfolio value after day 83: 12063826.46
# Portfolio value after day 84: 11949854.84
# Portfolio value after day 85: 11930792.44
# Portfolio value after day 86: 11899134.78
# Portfolio value after day 87: 11908705.61
# Portfolio value after day 88: 11972820.40
# Portfolio value after day 89: 12019639.10
# Portfolio value after day 90: 12032133.37
# Portfolio value after day 91: 12056179.20
# Portfolio value after day 92: 12129463.07
# Portfolio value after day 93: 12105603.71
# Portfolio value after day 94: 12164798.26
# Portfolio value after day 95: 12146821.49
# Portfolio value after day 96: 12105151.17
# Portfolio value after day 97: 12225736.46
# Portfolio value after day 98: 12220229.68
# Portfolio value after day 99: 12283660.04
# Portfolio value after day 100: 12773417.88
# Portfolio value after day 101: 12783621.97
# Portfolio value after day 102: 12760322.56
# Portfolio value after day 103: 12645441.97
# Portfolio value after day 104: 12716906.03
# Portfolio value after day 105: 12739096.66
# Portfolio value after day 106: 12746813.37
# Portfolio value after day 107: 12725420.72
# Portfolio value after day 108: 12780227.49
# Portfolio value after day 109: 12760610.57
# Portfolio value after day 110: 12813770.63
# Portfolio value after day 111: 12886220.90
# Portfolio value after day 112: 13002395.23
# Portfolio value after day 113: 12893618.13
# Portfolio value after day 114: 12934339.50
# Portfolio value after day 115: 12936381.44
# Portfolio value after day 116: 12930399.95
# Portfolio value after day 117: 12861444.23
# Portfolio value after day 118: 12956084.44
# Portfolio value after day 119: 12964888.62
# Portfolio value after day 120: 12960921.38
# Portfolio value after day 121: 12899876.46
# Portfolio value after day 122: 12954347.12
# Portfolio value after day 123: 13031554.25
# Portfolio value after day 124: 12974509.23
# Portfolio value after day 125: 12950636.58
# Portfolio value after day 126: 13002969.79
# Portfolio value after day 127: 13081306.43
# Portfolio value after day 128: 13081601.32
# Portfolio value after day 129: 13092765.65
# Portfolio value after day 130: 13115945.53
# Portfolio value after day 131: 13100028.43
# Portfolio value after day 132: 13100331.49
# Portfolio value after day 133: 13149082.25
# Portfolio value after day 134: 13088506.34
# Portfolio value after day 135: 13067406.63
# Portfolio value after day 136: 13080118.53
# Portfolio value after day 137: 13051592.15
# Portfolio value after day 138: 12985791.65
# Portfolio value after day 139: 13002864.09
# Portfolio value after day 140: 12997181.22
# Portfolio value after day 141: 13100369.74
# Portfolio value after day 142: 12991688.88
# Portfolio value after day 143: 13016017.18
# Portfolio value after day 144: 13165792.54
# Portfolio value after day 145: 13231426.32
# Portfolio value after day 146: 13284954.05
# Portfolio value after day 147: 13199098.80
# Portfolio value after day 148: 13212660.07
# Portfolio value after day 149: 13183396.67
# Portfolio value after day 150: 13135351.62
# Portfolio value after day 151: 13128935.58
# Portfolio value after day 152: 13096966.19
# Portfolio value after day 153: 13190387.60
# Portfolio value after day 154: 13223889.33
# Portfolio value after day 155: 13105483.33
# Portfolio value after day 156: 13141620.57
# Portfolio value after day 157: 13211151.10
# Portfolio value after day 158: 13089606.20
# Portfolio value after day 159: 13234558.26
# Portfolio value after day 160: 13274880.19
# Portfolio value after day 161: 13332976.00
# Portfolio value after day 162: 13333726.72
# Portfolio value after day 163: 13379058.11
# Portfolio value after day 164: 13412076.83
# Portfolio value after day 165: 13328424.68
# Portfolio value after day 166: 13405747.50
# Portfolio value after day 167: 13370196.62
# Portfolio value after day 168: 13349831.85
# Portfolio value after day 169: 13501976.55
# Portfolio value after day 170: 13578948.01
# Portfolio value after day 171: 13668373.37
# Portfolio value after day 172: 13646889.21
# Portfolio value after day 173: 13742245.60
# Portfolio value after day 174: 13731671.86
# Portfolio value after day 175: 13724650.67
# Portfolio value after day 176: 13796719.70
# Portfolio value after day 177: 13957594.93
# Portfolio value after day 178: 13886648.04
# Portfolio value after day 179: 13991875.11
# Portfolio value after day 180: 13939454.68
# Portfolio value after day 181: 13846587.94
# Portfolio value after day 182: 13808017.20
# Portfolio value after day 183: 13830557.43
# Portfolio value after day 184: 13805430.10
# Portfolio value after day 185: 13906127.98
# Portfolio value after day 186: 13899204.49
# Portfolio value after day 187: 13984992.74
# Portfolio value after day 188: 14028709.07
# Portfolio value after day 189: 14104244.92
# Portfolio value after day 190: 14103189.67
# Portfolio value after day 191: 14158161.66
# Portfolio value after day 192: 14181195.78
# Portfolio value after day 193: 14356399.01
# Portfolio value after day 194: 14336105.42
# Portfolio value after day 195: 14317850.97
# Portfolio value after day 196: 14323555.65
# Portfolio value after day 197: 14306303.42
# Portfolio value after day 198: 14351234.07
# Portfolio value after day 199: 14360605.67
# Portfolio value after day 200: 14301300.88
# Portfolio value after day 201: 14301857.80
# Portfolio value after day 202: 14355530.00
# Portfolio value after day 203: 14314728.79
# Portfolio value after day 204: 14254415.29
# Portfolio value after day 205: 14268317.61
# Portfolio value after day 206: 14301955.45
# Portfolio value after day 207: 14283414.18
# Portfolio value after day 208: 14302667.45
# Portfolio value after day 209: 14326894.63
# Portfolio value after day 210: 14282832.01
# Portfolio value after day 211: 14291261.96
# Portfolio value after day 212: 14305423.58
# Portfolio value after day 213: 14365498.50
# Portfolio value after day 214: 14336879.27
# Portfolio value after day 215: 14264624.14
# Portfolio value after day 216: 14275774.33
# Portfolio value after day 217: 14277380.06
# Portfolio value after day 218: 14290877.98
# Portfolio value after day 219: 14457301.91
# Portfolio value after day 220: 14480973.30
# Portfolio value after day 221: 14447111.15
# Portfolio value after day 222: 14592723.98
# Portfolio value after day 223: 14702678.04
# Portfolio value after day 224: 14702790.41
# Portfolio value after day 225: 14631777.40
# Portfolio value after day 226: 14652823.92
# Portfolio value after day 227: 14596917.05
# Portfolio value after day 228: 14589605.77
# Portfolio value after day 229: 14656372.97
# Portfolio value after day 230: 14737375.56
# Portfolio value after day 231: 14935841.79
# Portfolio value after day 232: 14969388.56
# Portfolio value after day 233: 14940144.71
# Portfolio value after day 234: 15092982.02
# Portfolio value after day 235: 15027423.38
# Portfolio value after day 236: 15093698.30
# Portfolio value after day 237: 15051260.16
# Portfolio value after day 238: 15098833.65
# Portfolio value after day 239: 15165924.71
# Portfolio value after day 240: 15149367.07
# Portfolio value after day 241: 15121378.74
# Portfolio value after day 242: 15151955.95
# Portfolio value after day 243: 15204986.46

# %%
plt.figure(figsize=(12, 6))
plt.plot(range(1, 244), portfolio_list, marker='o', linestyle='-', color='blue')
plt.title('Portfolio Value Over 10 Days')
plt.xlabel('Day')
plt.ylabel('Portfolio Value (INR)')
plt.xticks(range(1, 244))
plt.grid()
plt.show()

# %%
# Convert to numpy array
portfolio_values = np.array(portfolio_list)

# 1. Daily Returns
daily_returns = np.diff(portfolio_values) / portfolio_values[:-1]

# 2. Cumulative Return (Total % return)
cumulative_return = (portfolio_values[-1] / portfolio_values[0]) - 1

# 3. Sharpe Ratio (Assuming risk-free rate = 0 and 252 trading days/year)
sharpe_ratio = np.mean(daily_returns) / np.std(daily_returns) * np.sqrt(252)

# 4. Max Drawdown
running_max = np.maximum.accumulate(portfolio_values)
drawdown = (portfolio_values - running_max) / running_max
max_drawdown = drawdown.min()  # this will be negative

# 5. Count of Profit vs Loss Days
profit_days = np.sum(daily_returns > 0)
loss_days = np.sum(daily_returns < 0)

# === Print the results ===
print(f"Total Return: {cumulative_return*100:.2f}%")
print(f"Sharpe Ratio: {sharpe_ratio:.4f}")
print(f"Max Drawdown: {max_drawdown*100:.2f}%")
print(f"Profitable Days: {profit_days}, Loss Days: {loss_days}")
# Out:
# Total Return: 52.53%
# Sharpe Ratio: 5.4864
# Max Drawdown: -2.49%
# Profitable Days: 159, Loss Days: 83

# %%
import pickle
with open("2014-15_daily_portfolio.pkl", "wb") as f:
    pickle.dump(portfolio_list, f)
